# %% [markdown]
# <a href="https://colab.research.google.com/github/Wfelipetm/N3_M5/blob/main/N3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd

# Configurar pandas para mostrar todas as linhas
pd.set_option('display.max_rows', None)

# Leia o conteúdo do CSV fornecido
file_path = '/content/n3.csv'
df = pd.read_csv(file_path, sep=';', engine='python', encoding='latin1')

# Verifique se o dataframe tem apenas uma coluna
if df.shape[1] == 1:
    df = pd.read_csv(file_path, sep=',', engine='python', encoding='latin1')

# Verifique os nomes das colunas
print("Nomes das colunas:")
print(df.columns)

# Imprima as informações gerais sobre o conjunto de dados
print("\nInformações gerais sobre o conjunto de dados:")
print(df.info())

# Imprima as primeiras e últimas N linhas do arquivo
print("\nPrimeiras linhas do arquivo:")
print(df.head(1))

print("\nÚltimas linhas do arquivo:")
print(df.tail(1))

# cópia dos dados originais
df_clean = df.copy()

# Verifique a existência da coluna 'Calories'
if 'Calories' in df_clean.columns:
    # Substitua valores 'NaN' por 0 apenas na coluna 'Calories'
    df_clean['Calories'] = df_clean['Calories'].fillna(0)
    print("\nDados após substituir valores 'NaN' na coluna 'Calories' por 0:")
    print(df_clean)

else:
    print("\nA coluna 'Calories' não existe no conjunto de dados.")

# Verifique a existência da coluna 'Date' e substitua os valores nulos por '1900/01/01'
if 'Date' in df_clean.columns:
    df_clean['Date'].fillna('1900/01/01', inplace=True)
    # Imprima o conjunto de dados para verificar a mudança
    print("\nDados após substituir valores nulos na coluna 'Date' por '1900/01/01':")
    print(df_clean)

# Transforme os dados da coluna 'Date' em datetime
if 'Date' in df_clean.columns:
    try:
        df_clean['Date'] = pd.to_datetime(df_clean['Date'], format='%m/%d/%Y', errors='coerce')
        df_clean['Date'].replace(pd.to_datetime('1900-01-01'), pd.NaT, inplace=True)
    except ValueError as e:
        print(f"\nErro ao transformar a coluna 'Date' para datetime: {e}")

print("\nDados após transformar a coluna 'Date' para datetime:")
print(df_clean)

# Substitua '1900/01/01' por NaN na coluna 'Date'
if 'Date' in df_clean.columns:
    df_clean['Date'].replace('1900/01/01', pd.NaT, inplace=True)
    # Imprima o conjunto de dados para verificar a mudança
    print("\nDados após substituir '1900/01/01' por NaN na coluna 'Date':")
    print(df_clean)

# Corrija o valor "20201226" na coluna 'Date'
if 'Date' in df_clean.columns:
    df_clean['Date'] = df_clean['Date'].apply(lambda x: pd.to_datetime(x, format='%Y%m%d', errors='coerce') if isinstance(x, str) and len(x) == 8 else x)

# Tente novamente transformar os dados da coluna 'Date' em datetime
if 'Date' in df_clean.columns:
    try:
        df_clean['Date'] = pd.to_datetime(df_clean['Date'], errors='coerce')
    except ValueError as e:
        print(f"\nErro ao transformar a coluna 'Date' para datetime: {e}")

# Imprima o conjunto de dados para verificar as mudanças
print("\nDados após corrigir e transformar a coluna 'Date' para datetime:")
print(df_clean)

# Remova registros com valores nulos na coluna 'Date'
if 'Date' in df_clean.columns:
    df_clean.dropna(subset=['Date'], inplace=True)

# Imprime o dataframe e verifique se todas as transformações foram aplicadas
print("\nDados após remover registros com valores nulos na coluna 'Date':")
print(df_clean)
# Out:
# Nomes das colunas:
# Index(['ID', 'Duration', 'Date', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')
#
# Informações gerais sobre o conjunto de dados:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0